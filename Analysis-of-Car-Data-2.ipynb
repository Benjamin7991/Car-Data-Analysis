# %%
import pandas as pd

# %%
df = pd.read_csv('cars_data.csv')

# %%
df.head()
# Out:
#    Unnamed: 0                 Unnamed: 1 Unnamed: 2 Unnamed: 3    Unnamed: 4  \
# 0         NaN                        Car        MPG  Cylinders  Displacement
# 1         NaN                     STRING     DOUBLE        INT        DOUBLE
# 2         NaN  Chevrolet Chevelle Malibu       18.0          8         307.0
# 3         NaN          Buick Skylark 320       15.0          8         350.0
# 4         NaN         Plymouth Satellite       18.0          8         318.0
#
#    Unnamed: 5 Unnamed: 6    Unnamed: 7 Unnamed: 8 Unnamed: 9
# 0  Horsepower     Weight  Acceleration      Model     Origin
# 1      DOUBLE     DOUBLE        DOUBLE        INT        CAT
# 2       130.0       3504          12.0         70         US
# 3       165.0       3693          11.5         70         US
# 4       150.0       3436          11.0         70         US

# %%
new_cols = ['test', 'Car', 'MPG', 'Cylinders', 'Displacement', 'Horsepower', 'Weight', 'Acceleration', 'Model', 'Origin']

df.columns = new_cols

# %%
df.head()
# Out:
#    test                        Car     MPG  Cylinders  Displacement  \
# 0   NaN                        Car     MPG  Cylinders  Displacement
# 1   NaN                     STRING  DOUBLE        INT        DOUBLE
# 2   NaN  Chevrolet Chevelle Malibu    18.0          8         307.0
# 3   NaN          Buick Skylark 320    15.0          8         350.0
# 4   NaN         Plymouth Satellite    18.0          8         318.0
#
#    Horsepower  Weight  Acceleration  Model  Origin
# 0  Horsepower  Weight  Acceleration  Model  Origin
# 1      DOUBLE  DOUBLE        DOUBLE    INT     CAT
# 2       130.0    3504          12.0     70      US
# 3       165.0    3693          11.5     70      US
# 4       150.0    3436          11.0     70      US

# %%
del df['test']
df = df.drop(index= 0)
df = df.drop(index= 1)

# %%
df.head()
# Out:
#                          Car   MPG Cylinders Displacement Horsepower Weight  \
# 2  Chevrolet Chevelle Malibu  18.0         8        307.0      130.0   3504
# 3          Buick Skylark 320  15.0         8        350.0      165.0   3693
# 4         Plymouth Satellite  18.0         8        318.0      150.0   3436
# 5              AMC Rebel SST  16.0         8        304.0      150.0   3433
# 6                Ford Torino  17.0         8        302.0      140.0   3449
#
#   Acceleration Model Origin
# 2         12.0    70     US
# 3         11.5    70     US
# 4         11.0    70     US
# 5         12.0    70     US
# 6         10.5    70     US

# %% [markdown]
# # What European Cars are the lightest Weight?

# %%
df.dtypes
df.Origin = df.Origin.astype('string')
df.Horsepower = df.Horsepower.astype('float')

# %%
df.dtypes
# Out:
# Car              object
# MPG              object
# Cylinders        object
# Displacement     object
# Horsepower      float64
# Weight           object
# Acceleration     object
# Model            object
# Origin           string
# dtype: object

# %%
euro = df.drop(index=df[df['Origin'] != 'Europe'].index)

# %%
euro.tail()
# Out:
#                            Car   MPG Cylinders Displacement  Horsepower  \
# 368  Peugeot 505s Turbo Diesel  28.1         4        141.0        80.0
# 369                  Saab 900s     0         4        121.0       110.0
# 370               Volvo Diesel  30.7         6        145.0        76.0
# 385        Volkswagen Rabbit l  36.0         4        105.0        74.0
# 404          Volkswagen Pickup  44.0         4        97.00        52.0
#
#     Weight Acceleration Model  Origin
# 368   3230         20.4    81  Europe
# 369   2800         15.4    81  Europe
# 370   3160         19.6    81  Europe
# 385   1980         15.3    82  Europe
# 404   2130         24.6    82  Europe

# %%
df.Horsepower = df.Horsepower.astype('float')

# %%
df.dtypes
# Out:
# Car              object
# MPG              object
# Cylinders        object
# Displacement     object
# Horsepower      float64
# Weight           object
# Acceleration     object
# Model            object
# Origin           string
# dtype: object

# %%
euro = euro.sort_values(by ='Weight', ascending = True)

# %%
euro = euro.head(11)

# %%
euro['Car'] = euro['Car'] + ' ' + euro['Model']

# %%
euro = euro.drop_duplicates(subset ="Car", keep = 'first')

# %%
euro.reset_index()
# Out:
#    index                              Car   MPG Cylinders Displacement  \
# 0    212             Volkswagen Rabbit 76  29.5         4        97.00
# 1    227                 Renault 5 GTL 77  36.0         4        79.00
# 2     64          Volkswagen Model 111 71  27.0         4        97.00
# 3     27  Volkswagen 1131 Deluxe Sedan 70  26.0         4        97.00
# 4    339          Renault Lecar Deluxe 80  40.9         4        85.00
# 5    341             Volkswagen Rabbit 80  29.8         4        89.00
# 6    126                      Fiat 128 73  29.0         4        68.00
# 7    302      Volkswagen Rabbit Custom 79  31.9         4        89.00
# 8    184             Volkswagen Rabbit 75  29.0         4        90.00
# 9    242      Volkswagen Rabbit Custom 77  29.0         4        97.00
#
#    Horsepower Weight Acceleration Model  Origin
# 0        71.0   1825         12.2    76  Europe
# 1        58.0   1825         18.6    77  Europe
# 2        60.0   1834         19.0    71  Europe
# 3        46.0   1835         20.5    70  Europe
# 4         0.0   1835         17.3    80  Europe
# 5        62.0   1845         15.3    80  Europe
# 6        49.0   1867         19.5    73  Europe
# 7        71.0   1925         14.0    79  Europe
# 8        70.0   1937         14.0    75  Europe
# 9        78.0   1940         14.5    77  Europe

# %%
import matplotlib.pyplot as plt


#cars = [car for car, euro in euro.groupby('Car')]

plt.bar(euro['Car'], euro["Weight"])
plt.xticks(rotation = 'vertical')
plt.title('Top 10 Heaviest European Cars and their Weights')
plt.ylabel('Weight in Kg')

plt.show()

# %% [markdown]
# ### ^Above is the weights of the 10 heaviest European Cars from the Data

# %%
us = df.loc[df['Origin'] == 'US']

# %%
us
# Out:
#                            Car   MPG Cylinders Displacement  Horsepower  \
# 2    Chevrolet Chevelle Malibu  18.0         8        307.0       130.0
# 3            Buick Skylark 320  15.0         8        350.0       165.0
# 4           Plymouth Satellite  18.0         8        318.0       150.0
# 5                AMC Rebel SST  16.0         8        304.0       150.0
# 6                  Ford Torino  17.0         8        302.0       140.0
# ..                         ...   ...       ...          ...         ...
# 402           Chevrolet Camaro  27.0         4        151.0        90.0
# 403            Ford Mustang GL  27.0         4        140.0        86.0
# 405              Dodge Rampage  32.0         4        135.0        84.0
# 406                Ford Ranger  28.0         4        120.0        79.0
# 407                 Chevy S-10  31.0         4        119.0        82.0
#
#     Weight Acceleration Model Origin
# 2     3504         12.0    70     US
# 3     3693         11.5    70     US
# 4     3436         11.0    70     US
# 5     3433         12.0    70     US
# 6     3449         10.5    70     US
# ..     ...          ...   ...    ...
# 402   2950         17.3    82     US
# 403   2790         15.6    82     US
# 405   2295         11.6    82     US
# 406   2625         18.6    82     US
# 407   2720         19.4    82     US
#
# [254 rows x 9 columns]

# %%
us = us.sort_values('Weight')

# %%
us = us.head(10)
us.reset_index()
# Out:
#    index                          Car   MPG Cylinders Displacement  \
# 0    254                  Ford Fiesta  36.1         4        98.00
# 1    353               Plymouth Champ  39.0         4        86.00
# 2    304  Dodge Colt Hatchback Custom  35.7         4        98.00
# 3     65             Plymouth Cricket  26.0         4        91.00
# 4    204           Chevrolet Chevette  29.0         4        85.00
# 5    360               Ford Escort 4W  34.4         4        98.00
# 6     40                   Ford Pinto  25.0         4        98.00
# 7    246           Chevrolet Chevette  30.5         4        98.00
# 8    247               Dodge Colt m/m  33.5         4        98.00
# 9    320           Chevrolet Chevette  32.1         4        98.00
#
#    Horsepower Weight Acceleration Model Origin
# 0        66.0   1800         14.4    78     US
# 1        64.0   1875         16.4    81     US
# 2        80.0   1915         14.4    79     US
# 3        70.0   1955         20.5    71     US
# 4        52.0   2035         22.2    76     US
# 5        65.0   2045         16.2    81     US
# 6         0.0   2046         19.0    71     US
# 7        63.0   2051         17.0    77     US
# 8        83.0   2075         15.9    77     US
# 9        70.0   2120         15.5    80     US

# %%
us['Car'] = us['Car'] + ' ' + us['Model']

# %%
us
# Out:
#                                 Car   MPG Cylinders Displacement  Horsepower  \
# 254                  Ford Fiesta 78  36.1         4        98.00        66.0
# 353               Plymouth Champ 81  39.0         4        86.00        64.0
# 304  Dodge Colt Hatchback Custom 79  35.7         4        98.00        80.0
# 65              Plymouth Cricket 71  26.0         4        91.00        70.0
# 204           Chevrolet Chevette 76  29.0         4        85.00        52.0
# 360               Ford Escort 4W 81  34.4         4        98.00        65.0
# 40                    Ford Pinto 71  25.0         4        98.00         0.0
# 246           Chevrolet Chevette 77  30.5         4        98.00        63.0
# 247               Dodge Colt m/m 77  33.5         4        98.00        83.0
# 320           Chevrolet Chevette 80  32.1         4        98.00        70.0
#
#     Weight Acceleration Model Origin
# 254   1800         14.4    78     US
# 353   1875         16.4    81     US
# 304   1915         14.4    79     US
# 65    1955         20.5    71     US
# 204   2035         22.2    76     US
# 360   2045         16.2    81     US
# 40    2046         19.0    71     US
# 246   2051         17.0    77     US
# 247   2075         15.9    77     US
# 320   2120         15.5    80     US

# %%
del us['Model']

# %%
us.reset_index()
# Out:
#    index                             Car   MPG Cylinders Displacement  \
# 0    254                  Ford Fiesta 78  36.1         4        98.00
# 1    353               Plymouth Champ 81  39.0         4        86.00
# 2    304  Dodge Colt Hatchback Custom 79  35.7         4        98.00
# 3     65             Plymouth Cricket 71  26.0         4        91.00
# 4    204           Chevrolet Chevette 76  29.0         4        85.00
# 5    360               Ford Escort 4W 81  34.4         4        98.00
# 6     40                   Ford Pinto 71  25.0         4        98.00
# 7    246           Chevrolet Chevette 77  30.5         4        98.00
# 8    247               Dodge Colt m/m 77  33.5         4        98.00
# 9    320           Chevrolet Chevette 80  32.1         4        98.00
#
#    Horsepower Weight Acceleration Origin
# 0        66.0   1800         14.4     US
# 1        64.0   1875         16.4     US
# 2        80.0   1915         14.4     US
# 3        70.0   1955         20.5     US
# 4        52.0   2035         22.2     US
# 5        65.0   2045         16.2     US
# 6         0.0   2046         19.0     US
# 7        63.0   2051         17.0     US
# 8        83.0   2075         15.9     US
# 9        70.0   2120         15.5     US

# %%
import matplotlib.pyplot as plt


#cars = [car for car, euro in euro.groupby('Car')]

plt.bar(us['Car'], us["Weight"])
plt.xticks(rotation = 'vertical')
plt.title('Top 10 Heaviest American Cars and their Weights')
plt.ylabel('Weight in Kg')

plt.show()

# %% [markdown]
# ### ^then we found the top 10 heaviest american cars from the data

# %%
japan = df.loc[df['Origin'] == 'Japan']

# %%
japan = japan.sort_values('Weight', ascending =True)

# %%
japan = japan.head(10)
japan['Car'] = japan['Car'] + ' ' + japan['Model']

# %%
del japan['Model']

# %%
japan.reset_index()
# Out:
#    index                         Car   MPG Cylinders Displacement  Horsepower  \
# 0    400         Toyota Celica GT 82  32.0         4        144.0        96.0
# 1    180           Toyota Corolla 75  24.0         4        134.0        96.0
# 2    327  Toyota Corolla Liftback 80  29.8         4        134.0        90.0
# 3    252               Mazda RX-4 77  21.5         3        80.00       110.0
# 4    132           Toyota Mark II 73  20.0         6        156.0       122.0
# 5    250               Datsun 810 77  22.0         6        146.0        97.0
# 6    371          Toyota Cressida 81  25.4         6        168.0       116.0
# 7    342            Datsun 280-ZX 80  32.7         6        168.0       132.0
# 8    372        Datsun 810 Maxima 81  24.2         6        146.0       120.0
# 9    219           Toyota Mark II 76  19.0         6        156.0       108.0
#
#   Weight Acceleration Origin
# 0   2665         13.9  Japan
# 1   2702         13.5  Japan
# 2   2711         15.5  Japan
# 3   2720         13.5  Japan
# 4   2807         13.5  Japan
# 5   2815         14.5  Japan
# 6   2900         12.6  Japan
# 7   2910         11.4  Japan
# 8   2930         13.8  Japan
# 9   2930         15.5  Japan

# %%
import matplotlib.pyplot as plt


#cars = [car for car, euro in euro.groupby('Car')]

plt.bar(japan['Car'], japan["Weight"])
plt.xticks(rotation = 'vertical')
plt.title('Top 10 Heaviest Japanese Cars and their Weights')
plt.ylabel('Weight in Kg')

plt.show()
